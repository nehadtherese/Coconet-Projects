# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./Car_sales.csv')

# %%
data.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.tail(5)
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
data.sample(5)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 156        Volvo      S80              18.969                  NaN
# 116     Plymouth  Voyager              24.155               12.025
# 6           Audi       A8               1.380               39.000
# 140       Toyota   Tacoma              84.087                9.575
# 145   Volkswagen     Golf               9.761               11.425
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 156    Passenger              36.000          2.9       201.0      109.9
# 116          Car              18.850          2.4       150.0      113.3
# 6      Passenger              62.000          4.2       310.0      113.0
# 140          Car              11.528          2.4       142.0      103.3
# 145    Passenger              14.900          2.0       115.0       98.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %% [markdown]
# ### Null Values

# %%
data.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %% [markdown]
# #### Dropping Null Values

# %%
data.drop(columns= "__year_resale_value", inplace= True)

# %%
data.sample(5)
# Out:
#    Manufacturer          Model  Sales_in_thousands Vehicle_type  \
# 99   Mercedes-B          CL500               0.954    Passenger
# 44        Dodge        Durango             101.323          Car
# 89      Mercury  Grand Marquis              81.174    Passenger
# 63      Hyundai        Elantra              66.692    Passenger
# 42        Dodge        Ram Van              31.038          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 99              85.500          5.0       302.0      113.6   73.1   196.6
# 44              26.310          5.2       230.0      115.7   71.7   193.5
# 89              22.605          4.6       200.0      114.7   78.2   212.0
# 63              11.799          2.0       140.0      100.4   66.9   174.0
# 42              18.575          3.9       175.0      127.2   78.8   208.5
#
#     Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 99        4.115           23.2             20.0     4/11/2011
# ...

# %%
data.describe()
# Out:
#        Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# count          157.000000          155.000000   156.000000  156.000000
# mean            52.998076           27.390755     3.060897  185.948718
# std             68.029422           14.351653     1.044653   56.700321
# min              0.110000            9.235000     1.000000   55.000000
# 25%             14.114000           18.017500     2.300000  149.500000
# 50%             29.450000           22.799000     3.000000  177.500000
# 75%             67.956000           31.947500     3.575000  215.000000
# max            540.561000           85.500000     8.000000  450.000000
#
#         Wheelbase       Width      Length  Curb_weight  Fuel_capacity  \
# count  156.000000  156.000000  156.000000   155.000000     156.000000
# mean   107.487179   71.150000  187.343590     3.378026      17.951923
# std      7.641303    3.451872   13.431754     0.630502       3.887921
# ...

# %%
data.describe().T
# Out:
#                     count        mean        std         min         25%  \
# Sales_in_thousands  157.0   52.998076  68.029422    0.110000   14.114000
# Price_in_thousands  155.0   27.390755  14.351653    9.235000   18.017500
# Engine_size         156.0    3.060897   1.044653    1.000000    2.300000
# Horsepower          156.0  185.948718  56.700321   55.000000  149.500000
# Wheelbase           156.0  107.487179   7.641303   92.600000  103.000000
# Width               156.0   71.150000   3.451872   62.600000   68.400000
# Length              156.0  187.343590  13.431754  149.400000  177.575000
# Curb_weight         155.0    3.378026   0.630502    1.895000    2.971000
# Fuel_capacity       156.0   17.951923   3.887921   10.300000   15.800000
# Fuel_efficiency     154.0   23.844156   4.282706   15.000000   21.000000
# Power_perf_factor   155.0   77.043591  25.142664   23.276272   60.407707
#
#                            50%         75%         max
# ...

# %%
data.size
# Out:
# 2355

# %%
data.shape
# Out:
# (157, 15)

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'Vehicle_type',
#        'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency',
#        'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# ##### Data Types

# %%
data.Manufacturer.dtype
# Out:
# dtype('O')

# %%
data.Sales_in_thousands.dtype
# Out:
# dtype('float64')

# %%
data.Engine_size.dtype
# Out:
# dtype('float64')

# %%
data.Power_perf_factor.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Slicing

# %%
data.loc[50:55]
# Out:
#    Manufacturer           Model  Sales_in_thousands Vehicle_type  \
# 50         Ford           Focus             175.670    Passenger
# 51         Ford  Crown Victoria              63.403    Passenger
# 52         Ford        Explorer             276.747          Car
# 53         Ford        Windstar             155.787          Car
# 54         Ford      Expedition             125.338          Car
# 55         Ford          Ranger             220.650          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 50              12.315          2.0       107.0      103.0   66.9   174.8
# 51              22.195          4.6       200.0      114.7   78.2   212.0
# 52              31.930          4.0       210.0      111.6   70.2   190.7
# 53              21.410          3.0       150.0      120.7   76.6   200.9
# 54              36.135          4.6       240.0      119.0   78.7   204.6
# ...

# %%
data.iloc[:5]
# Out:
#   Manufacturer    Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0        Acura  Integra              16.919    Passenger               21.50
# 1        Acura       TL              39.384    Passenger               28.40
# 2        Acura       CL              14.114    Passenger                 NaN
# 3        Acura       RL               8.588    Passenger               42.00
# 4         Audi       A4              20.397    Passenger               23.99
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          1.8       140.0      101.2   67.3   172.4        2.639
# 1          3.2       225.0      108.1   70.3   192.9        3.517
# 2          3.2       225.0      106.9   70.6   192.0        3.470
# 3          3.5       210.0      114.6   71.4   196.6        3.850
# 4          1.8       150.0      102.6   68.2   178.0        2.998
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor
# ...

# %%
data.iloc[150:]
# Out:
#     Manufacturer   Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 150   Volkswagen  Beetle              49.463    Passenger                15.9
# 151        Volvo     S40              16.957    Passenger                23.4
# 152        Volvo     V40               3.545    Passenger                24.4
# 153        Volvo     S70              15.245    Passenger                27.5
# 154        Volvo     V70              17.531    Passenger                28.8
# 155        Volvo     C70               3.493    Passenger                45.5
# 156        Volvo     S80              18.969    Passenger                36.0
#
#      Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 150          2.0       115.0       98.9   67.9   161.1        2.769
# 151          1.9       160.0      100.5   67.6   176.6        2.998
# 152          1.9       160.0      100.5   67.6   176.6        3.042
# 153          2.4       168.0      104.9   69.3   185.9        3.208
# ...

# %% [markdown]
# ### Calling the Colums

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'Vehicle_type',
#        'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency',
#        'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data['Manufacturer']
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4       Audi
#        ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
data['Engine_size']
# Out:
# 0      1.8
# 1      3.2
# 2      3.2
# 3      3.5
# 4      1.8
#       ...
# 152    1.9
# 153    2.4
# 154    2.4
# 155    2.3
# 156    2.9
# Name: Engine_size, Length: 157, dtype: float64

# %%
data['Power_perf_factor']
# Out:
# 0       58.280150
# 1       91.370778
# 2             NaN
# 3       91.389779
# 4       62.777639
#           ...
# 152     66.498812
# 153     70.654495
# 154     71.155978
# 155    101.623357
# 156     85.735655
# Name: Power_perf_factor, Length: 157, dtype: float64

# %% [markdown]
# ### Value Counts

# %%
data.Manufacturer.value_counts()
# Out:
# Manufacturer
# Ford          11
# Dodge         11
# Chevrolet      9
# Mercedes-B     9
# Toyota         9
# Chrysler       7
# Mitsubishi     7
# Nissan         7
# Mercury        6
# Oldsmobile     6
# Lexus          6
# Pontiac        6
# Volvo          6
# Volkswagen     6
# Cadillac       5
# Honda          5
# Saturn         5
# Plymouth       4
# Buick          4
# Acura          4
# Audi           3
# BMW            3
# Lincoln        3
# Porsche        3
# Jeep           3
# Hyundai        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
data.Vehicle_type.value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
data.Latest_Launch.value_counts()
# Out:
# Latest_Launch
# 1/29/2012     2
# 1/4/2012      2
# 8/31/2011     2
# 5/6/2011      2
# 2/23/2012     2
#              ..
# 12/4/2012     1
# 7/7/2011      1
# 12/29/2012    1
# 8/1/2011      1
# 10/20/2011    1
# Name: count, Length: 130, dtype: int64

# %% [markdown]
# ### Unique

# %%
data.Model.unique()
# Out:
# array(['Integra', 'TL', 'CL', 'RL', 'A4', 'A6', 'A8', '323i', '328i',
#        '528i', 'Century', 'Regal', 'Park Avenue', 'LeSabre', 'DeVille',
#        'Seville', 'Eldorado', 'Catera', 'Escalade', 'Cavalier', 'Malibu',
#        'Lumina', 'Monte Carlo', 'Camaro', 'Corvette', 'Prizm', 'Metro',
#        'Impala', 'Sebring Coupe', 'Sebring Conv.', 'Concorde', 'Cirrus',
#        'LHS', 'Town & Country', '300M', 'Neon', 'Avenger', 'Stratus',
#        'Intrepid', 'Viper', 'Ram Pickup', 'Ram Wagon', 'Ram Van',
#        'Dakota', 'Durango', 'Caravan', 'Escort', 'Mustang', 'Contour',
#        'Taurus', 'Focus', 'Crown Victoria', 'Explorer', 'Windstar',
#        'Expedition', 'Ranger', 'F-Series', 'Civic', 'Accord', 'CR-V',
#        'Passport', 'Odyssey', 'Accent', 'Elantra', 'Sonata', 'I30',
#        'S-Type', 'Wrangler', 'Cherokee', 'Grand Cherokee', 'ES300',
#        'GS300', 'GS400', 'LS400', 'LX470', 'RX300', 'Continental',
# ...

# %%
data.Model.nunique()
# Out:
# 156

# %%
data.Wheelbase.nunique()
# Out:
# 88

# %% [markdown]
# ### Aggregate functions

# %%
data.Sales_in_thousands.mean()
# Out:
# np.float64(52.99807643312102)

# %%
data.Horsepower.max()
# Out:
# 450.0

# %%
data.Curb_weight.sum()
# Out:
# np.float64(523.594)

# %%
data.Fuel_capacity.min()
# Out:
# 10.3

# %%
data.Fuel_efficiency.sum()
# Out:
# np.float64(3672.0)

# %% [markdown]
# ### Sorting

# %%
 data.sort_values(by = 'Price_in_thousands')
# Out:
#     Manufacturer           Model  Sales_in_thousands Vehicle_type  \
# 26     Chevrolet           Metro              21.855    Passenger
# 62       Hyundai          Accent              41.184    Passenger
# 129       Saturn              SL              80.620    Passenger
# 140       Toyota          Tacoma              84.087          Car
# 63       Hyundai         Elantra              66.692    Passenger
# ..           ...             ...                 ...          ...
# 126      Porsche  Carrera Cabrio               1.866    Passenger
# 95    Mercedes-B        SL-Class               3.311    Passenger
# 99    Mercedes-B           CL500               0.954    Passenger
# 2          Acura              CL              14.114    Passenger
# 33      Chrysler  Town & Country              53.480          Car
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 26                9.235          1.0        55.0       93.1   62.6   149.4
# ...

# %%
data.sort_values(by = 'Sales_in_thousands', ascending = False, inplace= True)

# %%
data
# Out:
#     Manufacturer          Model  Sales_in_thousands Vehicle_type  \
# 56          Ford       F-Series             540.561          Car
# 52          Ford       Explorer             276.747          Car
# 137       Toyota          Camry             247.994    Passenger
# 49          Ford         Taurus             245.815    Passenger
# 58         Honda         Accord             230.902    Passenger
# ..           ...            ...                 ...          ...
# 125      Porsche  Carrera Coupe               1.280    Passenger
# 108   Oldsmobile        Cutlass               1.112    Passenger
# 99    Mercedes-B          CL500               0.954    Passenger
# 39         Dodge          Viper               0.916    Passenger
# 83    Mitsubishi         3000GT               0.110    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 56               26.935          4.6       220.0      138.5   79.1   224.5
# ...

# %% [markdown]
# ### Reset Index

# %%
data.reset_index(drop= True, inplace= True)

# %%
data
# Out:
#     Manufacturer          Model  Sales_in_thousands Vehicle_type  \
# 0           Ford       F-Series             540.561          Car
# 1           Ford       Explorer             276.747          Car
# 2         Toyota          Camry             247.994    Passenger
# 3           Ford         Taurus             245.815    Passenger
# 4          Honda         Accord             230.902    Passenger
# ..           ...            ...                 ...          ...
# 152      Porsche  Carrera Coupe               1.280    Passenger
# 153   Oldsmobile        Cutlass               1.112    Passenger
# 154   Mercedes-B          CL500               0.954    Passenger
# 155        Dodge          Viper               0.916    Passenger
# 156   Mitsubishi         3000GT               0.110    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                26.935          4.6       220.0      138.5   79.1   224.5
# ...

# %% [markdown]
# ### Filtering

# %%
data[data['Vehicle_type']== 'Car']
# Out:
#     Manufacturer           Model  Sales_in_thousands Vehicle_type  \
# 0           Ford        F-Series             540.561          Car
# 1           Ford        Explorer             276.747          Car
# 5          Dodge      Ram Pickup             227.061          Car
# 6           Ford          Ranger             220.650          Car
# 8          Dodge         Caravan             181.749          Car
# 10          Jeep  Grand Cherokee             157.040          Car
# 11          Ford        Windstar             155.787          Car
# 16          Ford      Expedition             125.338          Car
# 18         Dodge          Dakota             111.313          Car
# 20         Dodge         Durango             101.323          Car
# 25        Toyota          Tacoma              84.087          Car
# 30          Jeep        Cherokee              80.556          Car
# 34         Honda         Odyssey              76.029          Car
# ...

# %%
data[data['Sales_in_thousands']>200]
# Out:
#   Manufacturer       Model  Sales_in_thousands Vehicle_type  \
# 0         Ford    F-Series             540.561          Car
# 1         Ford    Explorer             276.747          Car
# 2       Toyota       Camry             247.994    Passenger
# 3         Ford      Taurus             245.815    Passenger
# 4        Honda      Accord             230.902    Passenger
# 5        Dodge  Ram Pickup             227.061          Car
# 6         Ford      Ranger             220.650          Car
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0              26.935          4.6       220.0      138.5   79.1   224.5
# 1              31.930          4.0       210.0      111.6   70.2   190.7
# 2              17.518          2.2       133.0      105.2   70.1   188.5
# 3              17.885          3.0       155.0      108.5   73.0   197.6
# 4              15.350          2.3       135.0      106.9   70.3   188.8
# ...

# %%
data[data['Engine_size']<1.5]
# Out:
#    Manufacturer  Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 95    Chevrolet  Metro              21.855    Passenger               9.235
#
#     Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 95          1.0        55.0       93.1   62.6   149.4        1.895
#
#     Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor
# 95           10.3             45.0     4/13/2012          23.276272

# %% [markdown]
# ### Dropping Multiple Colums

# %%
data.drop(columns=['Width', 'Length', 'Power_perf_factor'])
# Out:
#     Manufacturer          Model  Sales_in_thousands Vehicle_type  \
# 0           Ford       F-Series             540.561          Car
# 1           Ford       Explorer             276.747          Car
# 2         Toyota          Camry             247.994    Passenger
# 3           Ford         Taurus             245.815    Passenger
# 4          Honda         Accord             230.902    Passenger
# ..           ...            ...                 ...          ...
# 152      Porsche  Carrera Coupe               1.280    Passenger
# 153   Oldsmobile        Cutlass               1.112    Passenger
# 154   Mercedes-B          CL500               0.954    Passenger
# 155        Dodge          Viper               0.916    Passenger
# 156   Mitsubishi         3000GT               0.110    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Curb_weight  \
# 0                26.935          4.6       220.0      138.5        4.241
# ...

# %% [markdown]
# ### Groupby

# %%
data.groupby(['Vehicle_type', 'Manufacturer']) ['Sales_in_thousands'].mean().reset_index()
# Out:
#    Vehicle_type Manufacturer  Sales_in_thousands
# 0           Car     Cadillac           14.785000
# 1           Car     Chrysler           53.480000
# 2           Car        Dodge          111.541833
# 3           Car         Ford          263.816600
# 4           Car        Honda           54.029000
# 5           Car         Jeep           97.717667
# 6           Car        Lexus           30.182000
# 7           Car      Lincoln           22.925000
# 8           Car   Mercedes-B           28.976000
# 9           Car      Mercury           23.994500
# 10          Car   Mitsubishi           25.342500
# 11          Car       Nissan           47.261250
# 12          Car   Oldsmobile           22.189000
# 13          Car     Plymouth           24.155000
# 14          Car      Pontiac           39.572000
# 15          Car       Subaru           33.028000
# 16          Car       Toyota           50.511600
# 17    Passenger        Acura           19.751250
# ...

# %%
data.groupby(['Vehicle_type'])['Price_in_thousands'].sum().reset_index()
# Out:
#   Vehicle_type  Price_in_thousands
# 0          Car            1052.799
# 1    Passenger            3192.768

# %% [markdown]
# ### Querying the Data

# %%
data.query("Sales_in_thousands>250")
# Out:
#   Manufacturer     Model  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0         Ford  F-Series             540.561          Car              26.935
# 1         Ford  Explorer             276.747          Car              31.930
#
#    Engine_size  Horsepower  Wheelbase  Width  Length  Curb_weight  \
# 0          4.6       220.0      138.5   79.1   224.5        4.241
# 1          4.0       210.0      111.6   70.2   190.7        3.876
#
#    Fuel_capacity  Fuel_efficiency Latest_Launch  Power_perf_factor
# 0           25.1             18.0     8/16/2012          89.401935
# 1           21.0             19.0     4/25/2012          87.635496

# %%
data.query("Vehicle_type == 'Car' & Engine_size < 3")
# Out:
#    Manufacturer     Model  Sales_in_thousands Vehicle_type  \
# 6          Ford    Ranger             220.650          Car
# 8         Dodge   Caravan             181.749          Car
# 18        Dodge    Dakota             111.313          Car
# 25       Toyota    Tacoma              84.087          Car
# 35        Honda      CR-V              73.203          Car
# 38       Toyota   4Runner              68.411          Car
# 47         Jeep  Wrangler              55.557          Car
# 70       Subaru  Forester              33.028          Car
# 87       Toyota      RAV4              25.106          Car
# 91     Plymouth   Voyager              24.155          Car
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 6               12.050          2.5       119.0      117.5   69.4   200.7
# 8               19.565          2.4       150.0      113.3   76.8   186.3
# 18              16.980          2.5       120.0      131.0   71.5   215.0
# ...

# %% [markdown]
# ### Pivot Table

# %%
data.pivot_table(values='Price_in_thousands', index='Vehicle_type', columns='Manufacturer', aggfunc= 'sum')
# Out:
# Manufacturer  Acura    Audi    BMW    Buick  Cadillac  Chevrolet  Chrysler  \
# Vehicle_type
# Car             NaN     NaN    NaN      NaN    46.225        NaN     0.000
# Passenger      91.9  119.94  99.29  107.125   155.045    180.205   140.585
#
# Manufacturer    Dodge    Ford   Honda  ...  Oldsmobile  Plymouth  Pontiac  \
# Vehicle_type                           ...
# Car           122.205  128.46  73.150  ...      56.943     18.85   25.635
# Passenger     144.145  103.06  28.235  ...      96.794     71.72  112.060
#
# Manufacturer  Porsche   Saab  Saturn  Subaru   Toyota  Volkswagen  Volvo
# Vehicle_type
# Car               NaN    NaN     NaN  20.095  124.800         NaN    NaN
# Passenger      187.42  59.22  71.355  22.695   73.046      106.19  185.6
#
# [2 rows x 30 columns]

# %%
data.pivot_table(values='Horsepower', index= 'Vehicle_type', columns='Model', aggfunc= 'mean')
# Out:
# Model         3-Sep  3000GT   300M   323i   328i  4Runner  5-Sep   528i  \
# Vehicle_type
# Car             NaN     NaN    NaN    NaN    NaN    150.0    NaN    NaN
# Passenger     185.0   161.0  253.0  170.0  193.0      NaN  170.0  193.0
#
# Model            A4     A6  ...  Taurus  Town car    V40    V70  Villager  \
# Vehicle_type                ...
# Car             NaN    NaN  ...     NaN       NaN    NaN    NaN     170.0
# Passenger     150.0  200.0  ...   155.0     215.0  160.0  168.0       NaN
#
# Model         Viper  Voyager  Windstar  Wrangler  Xterra
# Vehicle_type
# Car             NaN    150.0     150.0     120.0   170.0
# Passenger     450.0      NaN       NaN       NaN     NaN
#
# [2 rows x 155 columns]

# %% [markdown]
# ### Cumilative Sum

# %%
data[['Sales_in_thousands', 'Price_in_thousands']].cumsum()
# Out:
#      Sales_in_thousands  Price_in_thousands
# 0               540.561              26.935
# 1               817.308              58.865
# 2              1065.302              76.383
# 3              1311.117              94.268
# 4              1542.019             109.618
# ..                  ...                 ...
# 152            8317.606            4046.747
# 153            8318.718            4064.892
# 154            8319.672            4150.392
# 155            8320.588            4220.117
# 156            8320.698            4245.567
#
# [157 rows x 2 columns]

# %% [markdown]
# ### Replace

# %%
data.Vehicle_type.replace({'Car':0, 'Passenger':1})
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 152    1
# 153    1
# 154    1
# 155    1
# 156    1
# Name: Vehicle_type, Length: 157, dtype: int64

# %% [markdown]
# ### Rename

# %%
data.rename(columns= {'Sales_in_thousands': 'Sales', 'Price_in_thousands': 'Price'}, inplace= True)

# %%
data
# Out:
#     Manufacturer          Model    Sales Vehicle_type   Price  Engine_size  \
# 0           Ford       F-Series  540.561          Car  26.935          4.6
# 1           Ford       Explorer  276.747          Car  31.930          4.0
# 2         Toyota          Camry  247.994    Passenger  17.518          2.2
# 3           Ford         Taurus  245.815    Passenger  17.885          3.0
# 4          Honda         Accord  230.902    Passenger  15.350          2.3
# ..           ...            ...      ...          ...     ...          ...
# 152      Porsche  Carrera Coupe    1.280    Passenger  71.020          3.4
# 153   Oldsmobile        Cutlass    1.112    Passenger  18.145          3.1
# 154   Mercedes-B          CL500    0.954    Passenger  85.500          5.0
# 155        Dodge          Viper    0.916    Passenger  69.725          8.0
# 156   Mitsubishi         3000GT    0.110    Passenger  25.450          3.0
#
# ...

# %% [markdown]
# ### Percentage Change

# %%
data['Pct_Change'] = data.Sales.pct_change()

# %%
data
# Out:
#     Manufacturer          Model    Sales Vehicle_type   Price  Engine_size  \
# 0           Ford       F-Series  540.561          Car  26.935          4.6
# 1           Ford       Explorer  276.747          Car  31.930          4.0
# 2         Toyota          Camry  247.994    Passenger  17.518          2.2
# 3           Ford         Taurus  245.815    Passenger  17.885          3.0
# 4          Honda         Accord  230.902    Passenger  15.350          2.3
# ..           ...            ...      ...          ...     ...          ...
# 152      Porsche  Carrera Coupe    1.280    Passenger  71.020          3.4
# 153   Oldsmobile        Cutlass    1.112    Passenger  18.145          3.1
# 154   Mercedes-B          CL500    0.954    Passenger  85.500          5.0
# 155        Dodge          Viper    0.916    Passenger  69.725          8.0
# 156   Mitsubishi         3000GT    0.110    Passenger  25.450          3.0
#
# ...

# %% [markdown]
# ### Smallest/Largest

# %%
data.nsmallest(5, 'Price')
# Out:
#    Manufacturer    Model   Sales Vehicle_type   Price  Engine_size  \
# 95    Chevrolet    Metro  21.855    Passenger   9.235          1.0
# 61      Hyundai   Accent  41.184    Passenger   9.699          1.5
# 29       Saturn       SL  80.620    Passenger  10.685          1.9
# 25       Toyota   Tacoma  84.087          Car  11.528          2.4
# 40      Hyundai  Elantra  66.692    Passenger  11.799          2.0
#
#     Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 95        55.0       93.1   62.6   149.4        1.895           10.3
# 61        92.0       96.1   65.7   166.7        2.240           11.9
# 29       100.0      102.4   66.4   176.9        2.332           12.1
# 25       142.0      103.3   66.5   178.7        2.580           15.1
# 40       140.0      100.4   66.9   174.0        2.626           14.5
#
#     Fuel_efficiency Latest_Launch  Power_perf_factor  Pct_Change
# 95             45.0     4/13/2012          23.276272   -0.046674
# ...

# %%
data.nlargest(5, 'Price')
# Out:
#     Manufacturer           Model  Sales Vehicle_type   Price  Engine_size  \
# 154   Mercedes-B           CL500  0.954    Passenger  85.500          5.0
# 147   Mercedes-B        SL-Class  3.311    Passenger  82.600          5.0
# 149      Porsche  Carrera Cabrio  1.866    Passenger  74.970          3.4
# 152      Porsche   Carrera Coupe  1.280    Passenger  71.020          3.4
# 155        Dodge           Viper  0.916    Passenger  69.725          8.0
#
#      Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 154       302.0      113.6   73.1   196.6        4.115           23.2
# 147       302.0       99.0   71.3   177.1        4.125           21.1
# 149       300.0       92.6   69.5   174.5        3.075           17.0
# 152       300.0       92.6   69.5   174.5        3.032           17.0
# 155       450.0       96.2   75.7   176.7        3.375           19.0
#
#      Fuel_efficiency Latest_Launch  Power_perf_factor  Pct_Change
# ...

# %% [markdown]
# ### Cut Method

# %%
cutoff = [9.235, 34.656, 60.078, 85.500]
labels = ['Budget', 'Mid_Range', 'Luxury']
data['Car_Type'] = pd.cut(data.Price, bins=cutoff, labels=labels)

# %%
data
# Out:
#     Manufacturer          Model    Sales Vehicle_type   Price  Engine_size  \
# 0           Ford       F-Series  540.561          Car  26.935          4.6
# 1           Ford       Explorer  276.747          Car  31.930          4.0
# 2         Toyota          Camry  247.994    Passenger  17.518          2.2
# 3           Ford         Taurus  245.815    Passenger  17.885          3.0
# 4          Honda         Accord  230.902    Passenger  15.350          2.3
# ..           ...            ...      ...          ...     ...          ...
# 152      Porsche  Carrera Coupe    1.280    Passenger  71.020          3.4
# 153   Oldsmobile        Cutlass    1.112    Passenger  18.145          3.1
# 154   Mercedes-B          CL500    0.954    Passenger  85.500          5.0
# 155        Dodge          Viper    0.916    Passenger  69.725          8.0
# 156   Mitsubishi         3000GT    0.110    Passenger  25.450          3.0
#
# ...

# %% [markdown]
# ### Crosstab

# %%
pd.crosstab(data.Vehicle_type, data.Price, margins= True)
# Out:
# Price         9.235  9.699  10.685  11.528  11.799  12.05  12.07  12.315  \
# Vehicle_type
# Car               0      0       0       1       0      1      0       0
# Passenger         1      1       1       0       1      0      1       1
# All               1      1       1       1       1      1      1       1
#
# Price         12.535  12.64  ...  54.005  60.105  62.0  69.7  69.725  71.02  \
# Vehicle_type                 ...
# Car                0      0  ...       0       1     0     0       0      0
# Passenger          1      2  ...       1       0     1     1       1      1
# All                1      2  ...       1       1     1     1       1      1
#
# Price         74.97  82.6  85.5  All
# Vehicle_type
# Car               0     0     0   40
# Passenger         1     1     1  115
# All               1     1     1  155
#
# [3 rows x 153 columns]
